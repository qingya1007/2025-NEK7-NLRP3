# %%
import numpy as np

import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
active_rmsd_1=np.loadtxt('rmsd_to_Active.dat',comments="#")
#inactive_rmsd_2=np.loadtxt('/home/jinp/project/NLRP3/active_no_NEK7/md8ej4/MD2/RMSDF/rmsd_active_deletednek7_ADP.dat',comments="#")
#inactive_rmsd_3=np.loadtxt('/home/jinp/project/NLRP3/active_no_NEK7/md8ej4/MD3/RMSDF/rmsd_active_deletednek7_ADP.dat',comments="#")


rmsd_to_inactive=np.loadtxt('rmsd_to_inactive.dat',comments="#")

# %%
x1 = rmsd_to_inactive[:,1]
#x2 = inactive_rmsd_2[:,1]
#x3 = inactive_rmsd_3[:,1]


y1 = active_rmsd_1[:,1]
#y2 = rmsd_to_active[:,1]
#y3 = rmsd_to_active[:,1]

# %%
x=np.array(x1)
y=np.array(y1)
xy=np.vstack([x,y])
z=gaussian_kde(xy)(xy)
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
plt.scatter(x1,y1)
#plt.scatter(x2,y2)
#plt.scatter(x3,y3)

# %%
import scienceplots as sp
plt.style.use('nature')

# %%
plt.figure(figsize=(2,1.8),dpi=300)
plt.xlabel('RMSD to Inactive  ($\AA$)',fontsize=6)
plt.ylabel('RMSD to Active  ($\AA$)',fontsize=6)
plt.scatter(x1,y1,s=0.8, c=z,cmap='rainbow',edgecolors=None,linewidths=None,alpha=1,vmin=0,vmax=0.45,label='A$_{withoutNEK7}$')
#plt.title("active_without_nek7",fontsize=13)
plt.xlim([0,27])
plt.ylim([0,33])
#plt.legend(loc=1,fontsize=4)
plt.yticks(np.arange(0, 44, step=11),fontsize=6)
plt.xticks(np.arange(0, 36, step=9),fontsize=6)
#plt.colorbar()
plt.legend( loc='lower left',fontsize=6)
fig=plt.scatter(20.6849,0,s=30,color='cyan',marker='*')

plt.savefig('scatter-rmsd_3_1.svg',bbox_inches='tight',transparent=True)

# %%
mean1,y1,s=0.8, color='magenta',
# Out:
#   Cell In[9], line 1
#     mean1,y1,s=0.8, color='magenta',
#                ^
# SyntaxError: cannot assign to literal
