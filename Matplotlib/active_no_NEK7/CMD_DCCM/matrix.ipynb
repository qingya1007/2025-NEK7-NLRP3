# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm
import seaborn as sns

# %%
data=np.loadtxt("active_noNEK7.txt")

# %%
print(data)
# Out:
# [[ 1.          0.99768289  0.99607271 ... -0.97187392 -0.95578964
#   -0.9405206 ]
#  [ 0.99768289  1.          0.99824105 ... -0.97747813 -0.96388485
#   -0.94937295]
#  [ 0.99607271  0.99824105  1.         ... -0.97524831 -0.96127996
#   -0.94624945]
#  ...
#  [-0.97187392 -0.97747813 -0.97524831 ...  1.          0.99493277
#    0.9854127 ]
#  [-0.95578964 -0.96388485 -0.96127996 ...  0.99493277  1.
#    0.99524182]
#  [-0.9405206  -0.94937295 -0.94624945 ...  0.9854127   0.99524182
#    1.        ]]

# %%
import scienceplots as sp
plt.style.use('nature')

# %%
plt.figure(figsize=(8,4),dpi=200)



plt.pcolormesh(data,cmap='rainbow')
#plt.xlim([1,6003])
#plt.ylim([192,384])
#plt.xticks(np.arange(1,191,20))
#plt.yticks(np.arange(0,6003,2001),np.arange(0,3000,1000))
plt.title('p53-ASPP2')
plt.show()
#plt.colorbar()


#plt.savefig('/home/teliu/work/aspp2/image/contact/p53-ASPP2.png',bbox_inches='tight',transparent=True)

# %%
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib as mpl
cmap = (mpl.colors.ListedColormap(['#FFA8FF','#FFC9FF','#FFD4FF' ,'white', 'white', '#D4FFFF','#A8FFFF','#80FFFF']))
bounds = [-1,-0.75,-0.5,-0.25, 0,0.25, 0.5,0.75,1]

#cmap = LinearSegmentedColormap.from_list('mycmap',[(-1, 'deeppink'),(-0.6, 'pink'),(-0.2, 'white'),(0, 'white'),(0.2, 'white'),(0.6,'deepskyblue'),(1, 'blue')])

# %%
#plt.figure(figsize=(2,1),dpi=200)
fig, ax1 = plt.subplots(figsize=(2.2,2.1),dpi=300)





ax=plt.pcolormesh(data,cmap=cmap,vmin=-1,vmax=1)



#plt.ylim([192,384])
plt.yticks(np.arange(0, 1043, step=149))
plt.xticks(np.arange(0, 1043, step=149))
plt.xlim([0,894])
plt.ylim([0,894])

#ax = plt.gca()  
a=[1,34,61,220,299,395,545,559]
#ax.invert_yaxis() 
plt.title('Active without NEK7',fontsize=8,pad=2)
#plt.colorbar()
ax1.set_xlabel('Residue Index',fontsize=8,labelpad=8)
ax1.set_ylabel('Residue Index',fontsize=8,labelpad=8)

plt.xticks(a,fontsize=8)
plt.yticks(a,fontsize=8)
#plt.show()
ax.axes.xaxis.set_ticklabels([])
ax.axes.yaxis.set_ticklabels([])



plt.savefig('DCCM.svg',bbox_inches='tight',transparent=True)

# %%
pwd
