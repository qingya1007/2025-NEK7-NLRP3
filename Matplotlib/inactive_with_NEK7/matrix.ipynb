# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm
import scienceplots as sp
plt.style.use('nature')
import seaborn as sns

# %%
import scienceplots as sp
plt.style.use('nature')

# %%
data1=np.loadtxt("densmap1_nek7.dat")

# %%
data2=np.loadtxt("densmap1_LRR.dat")

# %%
plt.figure(figsize=(2.2,2),dpi=300)



plt.contour(data1,cmap='Oranges',linewidths=0.6,levels=np.linspace(0,38.96,10))
plt.yticks(np.arange(50, 750, step=50))
plt.xticks(np.arange(150, 750, step=100))
plt.xlim([150,650])
plt.ylim([50,700])
plt.title('Inactive with NEK7',fontsize=8,pad=2)
plt.yticks([])
plt.xticks([])
#plt.colorbar()


plt.savefig('density_nek7.svg',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(2.2,2),dpi=300)



plt.contour(data2,cmap='Blues',linewidths=0.6,levels=np.linspace(0,38.960,10))
plt.yticks(np.arange(50, 750, step=50))
plt.xticks(np.arange(150, 750, step=100))
plt.xlim([150,650])
plt.ylim([50,700])
plt.title('Inactive with NEK7',fontsize=8,pad=2)
plt.yticks([])
plt.xticks([])
#plt.colorbar()


plt.savefig('density_lrr.svg',bbox_inches='tight',transparent=True)

# %%
pwd
# Out:
# '/home/jinp/project/NLRP3/CMD_density/inactive_with_NEK7'
