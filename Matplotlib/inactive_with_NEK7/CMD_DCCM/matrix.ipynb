# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import LogNorm
import seaborn as sns

# %%
data=np.loadtxt("inactive_addNEK7.txt")

# %%
print(data)
# Out:
# [[1.         0.99894069 0.99495228 ... 0.33593462 0.36033905 0.39147119]
#  [0.99894069 1.         0.99653397 ... 0.34613775 0.36981795 0.39613928]
#  [0.99495228 0.99653397 1.         ... 0.32124715 0.35630342 0.38746052]
#  ...
#  [0.33593462 0.34613775 0.32124715 ... 1.         0.97691368 0.92277384]
#  [0.36033905 0.36981795 0.35630342 ... 0.97691368 1.         0.96202937]
#  [0.39147119 0.39613928 0.38746052 ... 0.92277384 0.96202937 1.        ]]

# %%
import scienceplots as sp
plt.style.use('nature')

# %%
plt.figure(figsize=(8,4),dpi=200)



plt.pcolormesh(data,cmap='rainbow')
#plt.xlim([1,6003])
#plt.ylim([192,384])
#plt.xticks(np.arange(1,191,20))
#plt.yticks(np.arange(0,6003,2001),np.arange(0,3000,1000))
plt.title('p53-ASPP2')
plt.show()
#plt.colorbar()


#plt.savefig('/home/teliu/work/aspp2/image/contact/p53-ASPP2.png',bbox_inches='tight',transparent=True)

# %%
from matplotlib.colors import ListedColormap,LinearSegmentedColormap
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import matplotlib as mpl
cmap = (mpl.colors.ListedColormap(['#FFA8FF','#FFC9FF','#FFD4FF' ,'white', 'white', '#D4FFFF','#A8FFFF','#80FFFF']))
bounds = [-1,-0.75,-0.5,-0.25, 0,0.25, 0.5,0.75,1]

#cmap = LinearSegmentedColormap.from_list('mycmap',[(-1, 'deeppink'),(-0.6, 'pink'),(-0.2, 'white'),(0, 'white'),(0.2, 'white'),(0.6,'deepskyblue'),(1, 'blue')])

# %%
#plt.figure(figsize=(2,1),dpi=200)
fig, ax1 = plt.subplots(figsize=(2.2,2.1),dpi=300)





plt.pcolormesh(data,cmap=cmap,vmin=-1,vmax=1)



#plt.ylim([192,384])
plt.yticks(np.arange(0, 1043, step=149))
plt.xticks(np.arange(0, 1043, step=149))
plt.xlim([0,894])
plt.ylim([0,894])

#ax = plt.gca()  

#ax.invert_yaxis() 
plt.title('Inactive with NEK7',fontsize=8,pad=2)
#plt.colorbar()
#ax1.set_xlabel('Residue Index',fontsize=6,labelpad=0)
#ax1.set_ylabel('Residue Index',fontsize=6,labelpad=0)

plt.xticks([])
plt.yticks(fontsize=6)
#plt.show()
plt.yticks([])


plt.savefig('DCCM.svg',bbox_inches='tight',transparent=True)

# %%
pwd
# Out:
# '/home/jinp/project/NLRP3/CMD_DCCM/CMD_SS/inactive_with_NEK7'
